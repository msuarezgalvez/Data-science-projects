# %% [markdown]
# # Data Visualization Using Python/seaborn on Automobile Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
sns.set_style("white")

import warnings
warnings.filterwarnings('ignore')

# %%
auto = pd.read_csv("Automobile (1).csv")
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %%
auto.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Univariate distributions

# %%
sns.displot(auto['normalized_losses'], kde = False)
plt.xlabel("Normalized Losses")
# Out:
# Text(0.5, 8.95999999999998, 'Normalized Losses')

# %% [markdown]
# # Histograms

# %%
sns.displot(auto["city_mpg"], kde=True, rug=False)
plt.xlabel("City mpg")
# Out:
# Text(0.5, 8.95999999999998, 'City mpg')

# %% [markdown]
# # Bivariate distributions

# %%
# Scatter plot
sns.jointplot(auto['engine_size'], auto['horsepower'])

# %%
# Hex Bin Plots

sns.jointplot(auto['engine_size'], auto['horsepower'], kind="hex")

# %%
# Kernel Density Estimation

sns.jointplot(auto['engine_size'], auto['horsepower'], kind="kde")

# %% [markdown]
# # Visualizing pairwise relationships in a dataset

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']])

# %% [markdown]
# # Plotting with categorical data

# %%
sns.stripplot(auto['fuel_type'], auto['horsepower'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.swarmplot(auto['fuel_type'], auto['horsepower'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='horsepower'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(auto['number_of_doors'], auto['horsepower'], hue=auto['fuel_type'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %% [markdown]
# # Bar plots

# %%
sns.barplot(auto['body_style'], auto['horsepower'], hue=auto['engine_location'])
plt.legend(loc="upper center", title="Engine Location")

# %%
sns.countplot(auto['body_style'])
# Out:
# <AxesSubplot:xlabel='body_style', ylabel='count'>

# %% [markdown]
# # Point plots

# %%
sns.pointplot(auto['fuel_system'], auto['horsepower'], hue=auto['number_of_doors'])
plt.legend(title="Number of doors")
plt.xlabel("Fuel system")
plt.ylabel("Horsepower")
# Out:
# Text(0, 0.5, 'Horsepower')

# %%
sns.factorplot(x="fuel_type", 
               y="horsepower", 
               hue="number_of_doors", 
               col="engine_location", 
               data=auto, 
               kind="swarm")

# %%
sns.lmplot(x="horsepower", y="peak_rpm", data=auto)
plt.xlabel("Peak rpm")
plt.ylabel("Horsepower")
# Out:
# Text(-0.16499999999999915, 0.5, 'Horsepower')

# %%
sns.lmplot(x="horsepower", y="peak_rpm", hue="fuel_type", data=auto)
plt.xlabel("Horsepower")
plt.ylabel("Peak rpm")
# Out:
# Text(17.87587777777778, 0.5, 'Peak rpm')
